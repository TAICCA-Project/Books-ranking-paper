# %%
# 具有分類路徑、出版日期與ISBN13的爬蟲程式
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import logging
import re
import traceback
from datetime import datetime

# 設置日誌記錄（使用日期格式）
log_date = datetime.now().strftime('%Y%m%d')
log_filename = f'C:/Users/HP/Desktop/project/book-ranking/實體書排行榜code/log/sanmin_plog_{log_date}.txt'
logging.basicConfig(filename=log_filename, level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s')

# 基本設置
base_url = "https://www.sanmin.com.tw/promote/top/?id=yy&item=11410"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# 使用 session 來減少重複連線開銷
session = requests.Session()
data = []

# 設置自動重試機制
def fetch_with_retry(url, max_retries=3):
    """嘗試請求 URL，最多重試 max_retries 次"""
    for attempt in range(max_retries):
        try:
            response = session.get(url, headers=headers, timeout=10)
            if response.status_code == 200:
                return response
            else:
                print(f"⚠️ Attempt {attempt+1} failed: {response.status_code}")
                time.sleep(2)  # 延遲再試
        except requests.exceptions.RequestException as e:
            print(f"⚠️ Attempt {attempt+1} failed: {e}")
            time.sleep(2)
    return None  # 如果三次都失敗，返回 None

# 爬取每一頁的資料
for page in range(1, 14):
    url = f"{base_url}&pi={page}"
    response = session.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    logging.info(f"Processing page {page}")
    print(f"Processing page {page}")

    # 查找所有產品資訊
    products = soup.find_all('div', class_='sProduct')

    for product in products:
        try:
            rank = product.find('div', class_='Title').get_text(strip=True).split('.')[0]
            name = product.find('h3').get_text(strip=True)

            # 提取商品ID
            product_classes = product.get('class', [])
            product_id = None
            
            # 方法1：從 class 屬性中找到以 'Prod' 開頭且後面跟數字的類名
            for cls in product_classes:
                # 必須是 'Prod' + 數字的格式，例如 'Prod1234567'
                if cls.startswith('Prod') and len(cls) > 4 and cls[4:].isdigit():
                    product_id = cls[4:]  # 取 'Prod' 之後的數字部分
                    break
            
            # 方法2：如果找不到，嘗試從連結中提取
            if not product_id:
                link_tag = product.find('a', href=True)
                if link_tag and '/product/' in link_tag['href']:
                    # 從 URL 中提取 ID
                    match = re.search(r'/product/index/(\d+)', link_tag['href'])
                    if match:
                        product_id = match.group(1)
            
            # 方法3：嘗試從所有連結中提取
            if not product_id:
                all_links = product.find_all('a', href=True)
                for link in all_links:
                    match = re.search(r'/product/index/(\d+)', link['href'])
                    if match:
                        product_id = match.group(1)
                        break
            
            if not product_id:
                logging.warning(f"無法提取商品ID，跳過此商品: {name}")
                print(f"⚠️ 無法提取商品ID，跳過: {name}")
                continue
            
            detail_url = f"https://www.sanmin.com.tw/product/index/{product_id}"

            # 提取價格並清理格式（從列表頁）
            price_tag = product.select_one('.Price')
            if price_tag:
                price_text = price_tag.get_text(strip=True)
                # 移除非數字字符（保留小數點）
                price = re.sub(r'[^\d.]', '', price_text)
                if not price:
                    price = '未知'
            else:
                price = '未知'

            # 訪問商品詳細頁面
            detail_response = fetch_with_retry(detail_url)
            if detail_response is None:
                print(f"❌ Failed to fetch {detail_url} after retries")
                logging.error(f"Failed to fetch {detail_url} after retries")
                continue  # 跳過此書，避免影響後續爬取

            detail_soup = BeautifulSoup(detail_response.text, 'html.parser')


            # 提取分類路徑
            breadcrumb_tags = detail_soup.select('#breadcrumb-trail a')  # 直接選擇所有 <a> 標籤
            category_path = '-'.join([tag.get_text(strip=True) for tag in breadcrumb_tags if tag.get_text(strip=True) != "三民網路書店"]) if breadcrumb_tags else '未知'
            
            # 提取副分類（中文圖書分類）
            try:
                vice_category = ''
                # 查找所有 div.item
                item_divs = detail_soup.find_all('div', class_='item')
                for item_div in item_divs:
                    # 查找是否包含"中文圖書分類"
                    h2_tag = item_div.find('h2', class_='d-inline fs-14')
                    if h2_tag and '中文圖書分類' in h2_tag.get_text():
                        # 提取 h3 中的連結文本
                        h3_tag = item_div.find('h3', class_='d-inline fs-14')
                        if h3_tag:
                            link_tag = h3_tag.find('a', class_='text-blue bold')
                            if link_tag:
                                vice_category = link_tag.get_text(strip=True)
                                break
            except Exception as e:
                logging.error(f"Error extracting vice_category for product {product_id}: {e}")
                vice_category = ''
            
            # 一次性查找所有 li.ga 標籤，供多個字段使用
            li_tags = detail_soup.find_all('li', class_='ga')
            
            # 提取作者（從詳細頁）
            try:
                authors = ''
                for li in li_tags:
                    h3_tag = li.find('h3')
                    if h3_tag:
                        h3_text = h3_tag.get_text(strip=True)
                        # 檢查是否包含"作者"、"編者"、"著者"等關鍵字
                        if any(keyword in h3_text for keyword in ['作者', '編者', '著者', '編著']):
                            # 提取所有 a 標籤（作者可能有多個）
                            author_links = h3_tag.find_all('a')
                            if author_links:
                                authors = '; '.join([link.get_text(strip=True) for link in author_links])
                            else:
                                # 如果沒有 a 標籤，直接提取文本並清理
                                authors = re.sub(r'(作者|編者|著者|編著)[:：\s]*', '', h3_text).strip()
                            break
            except Exception as e:
                logging.error(f"Error extracting author for product {product_id}: {e}")
                authors = ''
            
            # 提取出版社（從詳細頁）
            try:
                publisher = ''
                for li in li_tags:
                    h3_tag = li.find('h3')
                    if h3_tag:
                        h3_text = h3_tag.get_text(strip=True)
                        # 檢查是否包含"出版社"關鍵字
                        if '出版社' in h3_text:
                            # 提取 a 標籤
                            pub_link = h3_tag.find('a')
                            if pub_link:
                                publisher = pub_link.get_text(strip=True)
                            else:
                                # 如果沒有 a 標籤，直接提取文本並清理
                                publisher = re.sub(r'出版社[:：\s]*', '', h3_text).strip()
                            break
            except Exception as e:
                logging.error(f"Error extracting publisher for product {product_id}: {e}")
                publisher = ''
            
            # 提取譯者（從詳細頁）
            try:
                translator = ''
                for li in li_tags:
                    h3_tag = li.find('h3')
                    if h3_tag:
                        h3_text = h3_tag.get_text(strip=True)
                        # 檢查是否包含"譯者"關鍵字
                        if '譯者' in h3_text:
                            # 提取所有 a 標籤（譯者可能有多個）
                            translator_links = h3_tag.find_all('a')
                            if translator_links:
                                translator = '; '.join([link.get_text(strip=True) for link in translator_links])
                            else:
                                # 如果沒有 a 標籤，直接提取文本並清理
                                translator = re.sub(r'譯者[:：\s]*', '', h3_text).strip()
                            break
            except Exception as e:
                logging.error(f"Error extracting translator for product {product_id}: {e}")
                translator = ''

            # 提取 ISBN13 並清理格式
            try:
                isbn13 = ''
                for li in li_tags:
                    if "ISBN13" in li.text:
                        # 提取 span 標籤中的 ISBN
                        isbn_span = li.find_all('span')
                        if len(isbn_span) >= 3:
                            isbn_text = isbn_span[-1].get_text(strip=True)
                        else:
                            isbn_text = li.get_text(strip=True).replace('ISBN13', '').replace('：', '').strip()
                        
                        # 移除破折號和空格
                        isbn13 = re.sub(r'[-\s]', '', isbn_text)
                        break
            except Exception as e:
                logging.error(f"Error extracting ISBN13 for product {product_id}: {e}")
                isbn13 = ''

            # 提取出版日期並轉換格式
            try:
                pub_date = ''
                for li in li_tags:
                    if "出版日" in li.text:
                        # 提取 span 標籤中的日期
                        date_span = li.find_all('span')
                        if len(date_span) >= 3:
                            pub_date_text = date_span[-1].get_text(strip=True)
                        else:
                            pub_date_text = li.get_text(strip=True).replace('出版日', '').replace('：', '').strip()
                        
                        # 轉換日期格式：YYYY/MM/DD 或 YYYY-MM-DD -> YYYY/M/D（去除前導0）
                        date_match = re.match(r'(\d{4})[-/](\d{1,2})[-/](\d{1,2})', pub_date_text)
                        if date_match:
                            year = date_match.group(1)
                            month = str(int(date_match.group(2)))  # 去除前導0
                            day = str(int(date_match.group(3)))    # 去除前導0
                            pub_date = f"{year}/{month}/{day}"
                        else:
                            pub_date = pub_date_text
                        break
            except Exception as e:
                logging.error(f"Error extracting PubDate for product {product_id}: {e}")
                pub_date = ''
            
            # 提取原文書名（替代書名）
            try:
                original_title = ''
                for li in li_tags:
                    if "替代書名" in li.text:
                        # 提取 a 標籤或 span 標籤中的書名
                        title_link = li.find('a')
                        if title_link:
                            original_title = title_link.get_text(strip=True)
                        else:
                            title_span = li.find_all('span')
                            if len(title_span) >= 3:
                                original_title = title_span[-1].get_text(strip=True)
                        break
            except Exception as e:
                logging.error(f"Error extracting OriginalTitle for product {product_id}: {e}")
                original_title = ''

            # 提取多個定位關鍵字的內容
            schemes = []
            keywords = ["三民出版品", "親子館", "中文圖書分類", "得獎作品"]
            for scheme_type in keywords:
                scheme_tag = detail_soup.find('a', class_='text-secondary bold', text=scheme_type)
                if scheme_tag:
                    main_title = scheme_tag.get_text(strip=True)
                    sub_titles = scheme_tag.find_parent('div', class_='text-secondary py3').find_all('h3', class_='d-inline fs-14')
                    for sub_title in sub_titles:
                        sub_text = sub_title.get_text(strip=True)
                        schemes.append(f"{main_title}-{sub_text}")

            scheme_text = '; '.join(schemes) if schemes else '未知'
            
            # 處理標題：移除標點符號和空格
            processed_title = re.sub(r'[^\w]', '', name)

            # 添加資料
            data.append({
                "ISBN": isbn13,
                "production_id": product_id,
                "title": name,
                "processed_title": processed_title,
                "Publisher": publisher,
                "author": authors,
                "translator": translator,  # 從詳細頁提取
                "original_title": original_title,  # 從"替代書名"提取
                "publish_date": pub_date,
                "fixed_price": price,
                "category": category_path,
                "vice_category": vice_category,  # 中文圖書分類的子分類
                "url": detail_url,
                "Day_counts": "",
                "rank": rank  # 用於後面填充日期欄位
            })

            logging.info(f"✅ 排名 {rank}: {name} (ID: {product_id})")
            print(f"✅ 排名 {rank}: {name}")
        except AttributeError as e:
            logging.error(f"❌ 解析商品時發生錯誤: {e}")
            print(f"❌ 解析商品時發生錯誤: {e}")
            continue
        except Exception as e:
            logging.error(f"❌ 處理商品時發生未預期錯誤: {e}")
            print(f"❌ 處理商品時發生未預期錯誤: {e}")
            traceback.print_exc()
            continue

    # 暫停以避免被伺服器禁止
    time.sleep(2)

# 保存資料到CSV文件（金石堂格式）
df = pd.DataFrame(data)

# 獲取今天的日期（格式：11/25）
today = datetime.now()
date_column = f"{today.month}/{today.day}"

# 添加日期欄位並填充排名
df[date_column] = df['rank']
df = df.drop('rank', axis=1)

# 調整欄位順序（三民增加 vice_category）
column_order = ['ISBN', 'production_id', 'title', 'processed_title', 'Publisher', 
                'author', 'translator', 'original_title', 'publish_date', 'fixed_price', 
                'category', 'vice_category', 'url', 'Day_counts', date_column]
df = df[column_order]

# 使用日期命名檔案
file_date = today.strftime('%Y%m%d')
output_path = f'C:/Users/HP/Desktop/project/book-ranking/ranking_result/sanmin/sanmin_all_categories_{file_date}.csv'
df.to_csv(output_path, index=False, encoding='utf-8-sig')

logging.info(f"資料已保存到 {output_path}")
print(f"資料已保存到 {output_path}")
print(f"共爬取 {len(df)} 筆資料")
# Out:
# Processing page 1
# ✅ 排名 1: 親愛的末期癌症：蔡康永真情推薦！低谷總裁的二十堂生命體悟課
# C:\Users\HP\AppData\Local\Temp\ipykernel_59584\1281126030.py:274: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   scheme_tag = detail_soup.find('a', class_='text-secondary bold', text=scheme_type)
# ✅ 排名 2: Amy Gets Eaten
# ✅ 排名 3: We Went to Find a Woolly Mammoth
# ✅ 排名 4: 主題百匯高中英文克漏字
# ✅ 排名 5: 古今悅讀一百
# ✅ 排名 6: 主題百匯高中英文閱讀測驗：篇章結構．閱讀測驗．混合題
# ✅ 排名 7: 原子習慣：細微改變帶來巨大成就的實證法則
# ✅ 排名 8: 中國仙道之究竟第一集：內金丹法
# ✅ 排名 9: 培育絕美鹿角蕨：進階栽培×配置設計，兼顧收藏與裝飾的綠植美學
# ✅ 排名 10: 2026年故宮國寶聚焦：書畫精品選粹大月曆
# ✅ 排名 11: 技術型高中英文第三冊職場多益TOEIC Up!(A版)(附解析夾冊)
# ✅ 排名 12: 學測歷屆試題：自然考科（107～114年）
# ✅ 排名 13: 國防產業地緣政治學【全民必備．第一本全球軍工產業分析全解讀】：從重工業、軟體業、航太業到AI技術轉型，揭祕軍工產業最新數據，看懂全球防衛布局，打造政經投資視野！
# ✅ 排名 14: 台灣AI大未來：解析最新的AI趨勢、台灣情勢、企業布局與個人發展
# ✅ 排名 15: 中共間諜戰術全解析：800 起真實案例，前美國中情局官員揭露全球共諜行動的面貌
# ✅ 排名 16: 對話式高中數學1-2冊學測複習講義
# ✅ 排名 17: 月考王：地理1
# ✅ 排名 18: 學測歷屆試題：國文（107～114年）
# ✅ 排名 19: 新譯老子讀本(四版)
# ✅ 排名 20: 人體透視書
# ✅ 排名 21: 小雲的飄浮日記
# ✅ 排名 22: 修仙寶典（天機秘文）
# ✅ 排名 23: 中國仙道之究竟第三集：女金丹法
# ✅ 排名 24: 技術型高中英文第一冊學習講義(A版)(附解析夾冊)
# ✅ 排名 25: 國家為什麼會破產：橋水基金應對大週期的原則
# ✅ 排名 26: 學測歷屆試題：英文（107～114年）
# ✅ 排名 27: 新譯古文觀止(上/下)(增訂五版)
# ✅ 排名 28: 神奇咒語咕哩咚
# ✅ 排名 29: 新基本小六法（2025年9月）
# ✅ 排名 30: 社會心理學
# ✅ 排名 31: 憲法釋論(修訂五版)
# ✅ 排名 32: 新譯孫子讀本(三版)
# ✅ 排名 33: 最新綜合六法全書(2025年9月版)
# ✅ 排名 34: 小學生國語辭典(增訂五版一刷)
# ✅ 排名 35: 中國仙道之究竟第二集：性命篇
# ✅ 排名 36: 領航高中地理1
# ✅ 排名 37: 學測歷屆試題：數學（107～114年）
# ✅ 排名 38: 學測3800全國高中模擬試題彙編：自然考科
# ✅ 排名 39: 大人學獨自升級：真正的升級是擴大舒適圈【職場終極奧義】
# ✅ 排名 40: 新譯易經讀本(三版)
# Processing page 2
# ✅ 排名 41: 成語典(增訂四版)
# ✅ 排名 42: 未來預知術
# ✅ 排名 43: 財務管理
# ✅ 排名 44: 新譯帛書老子
# ✅ 排名 45: 新譯金剛經(二版)
# ✅ 排名 46: 現代國際法(修訂五版)
# ✅ 排名 47: 中國仙道之究竟第四集：天仙心傳
# ✅ 排名 48: Dog Man #4: Dog Man and Cat Kid (全彩平裝本)(Graphic Novel)
# ✅ 排名 49: 學測歷屆試題：社會考科（107～114年）
# ✅ 排名 50: 超業女王林家榛：從天天掛蛋到年年超標，我用「陪伴成交」順勢滾出大雪球業績。
# ✅ 排名 51: 技術型高中英文第五冊習作(B版)
# ✅ 排名 52: 敘事電影與性別論述
# ✅ 排名 53: 鄭子太極拳自修新法
# ✅ 排名 54: 學測3800全國高中模擬試題彙編：數學A考科
# ✅ 排名 55: 普通型高中國文語文養成習作(五)
# ✅ 排名 56: Dog Man #2: Unleashed (全彩平裝版)(Graphic Novel)
# ✅ 排名 57: 我的奮鬥（上、下卷合訂完整本）（簡體版）（三版）
# ✅ 排名 58: 月考王：地球科學（全）
# ✅ 排名 59: 月考王：歷史1
# ✅ 排名 60: 大家的日本語：初級I（改訂版）
# ✅ 排名 61: 國際貿易實務新論(修訂十九版)
# ✅ 排名 62: Vocabulary 4001～7000 Exercise Book－進階必考3000單字實戰題本
# ✅ 排名 63: 債法原理：基本理論債之發生、契約、無因管理（增訂5版）（精）
# ✅ 排名 64: 新譯鬼谷子(增訂二版)
# ✅ 排名 65: 紅樓夢(上/下)(三版)
# ✅ 排名 66: 學典(增訂三版)
# ✅ 排名 67: 數獨隨身玩：國王級
# ✅ 排名 68: 50歲起這樣練，慢老中醫帶你增肌減脂、抗發炎、防失智：華佗80代傳人的凍齡導引術
# ✅ 排名 69: 全新！新制多益TOEIC 單字大全：備考多益唯一推薦權威單字書！不論題型如何變化，內容持續更新，常考字彙表達完全掌握，準確度最高！（附音檔下載QR碼）
# ✅ 排名 70: 紅太陽是怎樣升起的：延安整風運動的來龍去脈
# ✅ 排名 71: 中國仙道之究竟第五集：現代道家養生法
# ✅ 排名 72: 中國仙道之究竟第六集：文始真經新釋
# ✅ 排名 73: 永續發展基礎能力測驗經典講義與試題
# ✅ 排名 74: 學測3800全國高中模擬試題彙編：國文考科
# ✅ 排名 75: 穩定幣：數位金融的未來
# ✅ 排名 76: 逆愛戲劇寫真書
# ✅ 排名 77: 自學日語50音習字帖：專屬下載真人50音 QR Code
# ✅ 排名 78: 對話式講義高中數學第1冊
# ✅ 排名 79: 月考王：英文1
# ✅ 排名 80: 超模自然科學測全真模擬題本
# Processing page 3
# ✅ 排名 81: 最新！新制多益TOEIC閱讀題庫解析：最新收錄精準 10 回模擬試題！每月進場實測分析、完整傳授答題技巧，黃金證書手到擒來！（雙書裝＋單字音檔下載QR碼）
# ✅ 排名 82: 月考王：公民與社會1乙版
# ✅ 排名 83: 對話式講義高中數學Ａ第3冊
# ✅ 排名 84: 對話式高中數學3A-4A冊學測複習講義
# ✅ 排名 85: 用一本書詳解量價操作法，讓我股票賺3倍：200張Ｋ線圖看透主力和法人，在低價買進的軌跡！
# ✅ 排名 86: 論語接著講套書（共十冊）
# ✅ 排名 87: 全國高中月考期考試題挖挖哇：公民與社會1
# ✅ 排名 88: 福報：人與人之間真正的差距
# ✅ 排名 89: 數獨隨身玩：騎士級
# ✅ 排名 90: 新譯抱朴子(上)(二版)
# ✅ 排名 91: 新基本小六法（2025年3月）
# ✅ 排名 92: 新譯學庸讀本(二版)
# ✅ 排名 93: 小學生國語辭典(增訂六版一刷)
# ✅ 排名 94: 鏈鋸人09
# ✅ 排名 95: 行政法之理論與實用（增訂十六版）
# ✅ 排名 96: 國音及說話(修訂二版)
# ✅ 排名 97: 新辭典（精印本）
# ✅ 排名 98: 月考王：國文1
# ✅ 排名 99: 全國高中月考期考試題挖挖哇：歷史1
# ✅ 排名 100: 新日檢完勝500題N4－N5：文字‧語彙‧文法
# ✅ 排名 101: 115年農民曆（附太歲符）
# ✅ 排名 102: 115年農民曆（附萬年曆）
# ✅ 排名 103: 學測3800全國高中模擬試題彙編：英文考科
# ✅ 排名 104: 全國高中月考期考試題挖挖哇：數學1
# ✅ 排名 105: 全國高中月考期考試題挖挖哇：地理1
# ✅ 排名 106: 學測週計畫：地球科學
# ✅ 排名 107: 漫畫易經
# ✅ 排名 108: 解密粒線體02：光營養優化粒線體－從量子生物學掌握能量醫學，療癒身心靈
# ✅ 排名 109: 好好學生物學測總複習講義
# ✅ 排名 110: 全新！我的第一本自然發音記單字：教育部2000單字開口一唸就記住（附 發音口訣＋拼字＋例句QR 碼線上音檔）
# ✅ 排名 111: 新關鍵圖解地球科學學測總複習講義
# ✅ 排名 112: 刑法分則（一）
# ✅ 排名 113: 普通型高中國文語文養成習作(三)
# ✅ 排名 114: 持續買進：資料科學家的投資終極解答，存錢及致富的實證方法
# ✅ 排名 115: 膝蓋痠痛，自己可以救：完全圖解「黑澤式膝蓋自療法」，神奇3招輕鬆做，2週緩解疼痛、穩固關節靈活（暢銷新版）
# ✅ 排名 116: 英文科歷屆統測試題(含詳解本)(增訂八版)
# ✅ 排名 117: 寫作，是最好的自我投資【改寫命運暢銷版】：從注意力到思想複利，掌握AI時代的競爭優勢，把文字煉成最強人生資產！
# ✅ 排名 118: 脂評本紅樓夢（上／下不分售）
# ✅ 排名 119: 全國高中月考期考試題挖挖哇：國文1
# ✅ 排名 120: 學測週計畫：化學
# Processing page 4
# ✅ 排名 121: 學測週計畫：生物
# ✅ 排名 122: 大家的日本語：初級II（改訂版）(B5)
# ✅ 排名 123: 必考4000單字實戰題本VOCABULARY 4000 EXERCISE BOOK(修訂二版)
# ✅ 排名 124: 山水與古典(三版)
# ✅ 排名 125: 新譯楞嚴經(三版)
# ✅ 排名 126: 鬼滅之刃17
# ✅ 排名 127: 50天搞定新制多益核心單字(附隨堂評量夾冊)(增訂三版)
# ✅ 排名 128: 新譯四書讀本(七版)
# ✅ 排名 129: 新加坡與馬來西亞史：東西航道的樞紐
# ✅ 排名 130: TV動畫『鬼滅之刃』 公式角色書：參之卷
# ✅ 排名 131: 國貿業務丙級檢定學術科教戰守策(含活動夾冊)(修訂十七版)
# ✅ 排名 132: 新譯黃庭經‧陰符經(二版)
# ✅ 排名 133: 啊姆要吃好多好多
# ✅ 排名 134: 核心英文字彙力2001～4500 (附100回習題本附冊)(三版)
# ✅ 排名 135: 新譯古文觀止綜合評鑑(三版)
# ✅ 排名 136: 害羞一族
# ✅ 排名 137: 哲學概論(二版)
# ✅ 排名 138: 行政學
# ✅ 排名 139: 海底深潛大冒險
# ✅ 排名 140: 搶救國文大作戰（108課綱適用）
# ✅ 排名 141: 來自巴夏的生命訊息：日本熱銷200萬冊，解答你對此生的所有疑問
# ✅ 排名 142: 全新制怪物講師教學團隊的TOEIC多益5回全真模擬試題＋解析【修訂版】（2書＋1CD＋文法教學影片＋「Youtor App」內含VRP虛擬點讀筆）
# ✅ 排名 143: 靈魂的旅程
# ✅ 排名 144: 心理與教育研究法
# ✅ 排名 145: 技術型高中英文第一冊課堂講義習作(C版)(附解析附冊)
# ✅ 排名 146: 技術型高中英文第一冊課堂講義習作(C版)(附解析附冊)
# ✅ 排名 147: Kay's Marvellous Medicine: A Gross and Gruesome History of the Human Body
# ✅ 排名 148: Return to FACTopia! : Follow the Trail of 400 More Facts (Factopia! 2)(英國版)(精裝本)
# ✅ 排名 149: 電梯小鳥愛幫忙
# ✅ 排名 150: 長期買進：財金教授周冠男的42堂自制力投資課
# ✅ 排名 151: 美中開戰的終極指南【川普欽點白宮核心貿易顧問解密】：45個台灣必須掌握的地緣政治關鍵問答，從川普思維的底層邏輯，看懂世紀強權之爭的未來布局
# ✅ 排名 152: 日本語GOGOGO 1 練習帳【增訂版】
# ✅ 排名 153: 易經白話講座：64卦，卦卦讓你找到內在真實的力量
# ✅ 排名 154: 這僅有一次的人生，一定要讀蘇東坡：不管你遇到了什麼，一句蘇東坡就能療癒。
# ✅ 排名 155: 毓老師講《尚書》: 堯典、舜典、皋陶謨、甘誓、湯誓、洪範、立政、秦誓
# ✅ 排名 156: 超模數學A學測全真模擬題本
# ✅ 排名 157: 【學霸筆記】歷史（108課綱適用）
# ✅ 排名 158: Wind-Up Pirate Ship (玩具書)*附海盜船*
# ✅ 排名 159: 2026故宮文物日曆
# ✅ 排名 160: 好好學英文學測總複習
# Processing page 5
# ✅ 排名 161: 模模考數學A學測模考試題本
# ✅ 排名 162: 【學霸筆記】地理（108課綱適用）
# ✅ 排名 163: 滿級分歷史學測總複習講義
# ✅ 排名 164: 月考王：英文3
# ✅ 排名 165: 國際行銷學：建構全球行銷能力
# ✅ 排名 166: 數學掌心雷(108課綱)(二版)
# ✅ 排名 167: 紅太陽是怎樣升起的：延安整風運動的來龍去脈 (簡體書)
# ✅ 排名 168: 雷擊作戰：台海戰爭的預兆、爆發與未來結局
# ✅ 排名 169: 後期日中戰爭：太平洋戰爭下的中國戰場
# ✅ 排名 170: 如果歷史是一群喵15：大清風雲篇【萌貓漫畫學歷史】
# ✅ 排名 171: 一眼看穿大戶的戰術：圖解22種騙線、甩轎、吃貨、下車手法！
# ✅ 排名 172: 學測週計畫：物理
# ✅ 排名 173: 全國高中月考期考試題挖挖哇：物理（全）
# ✅ 排名 174: 普通型高中學科制霸公民與社會第一冊
# ✅ 排名 175: 醫師國考醫學生理學
# ✅ 排名 176: 速攻！圖解國學常識
# ✅ 排名 177: 膳食療養學實驗
# ✅ 排名 178: 刑事訴訟法（下冊）
# ✅ 排名 179: 今天煮什麼？：型男主廚吳秉承的百搭美味方程式，活用15種食材╳6種鍋具小家電，教你又快又省錢，搞定一桌超營養料理！【限量珍藏親簽版】
# ✅ 排名 180: 普通型高中選修物理Ⅰ學習講義(含解答本)
# ✅ 排名 181: 蛤蟆先生去看心理師（暢銷300萬冊！英國心理諮商經典，附《蛤蟆先生勇氣藏書卡》組）
# ✅ 排名 182: iPAS 經濟部產業人才 AI應用規劃師(初級)【114年最新版】
# ✅ 排名 183: 文學概論
# ✅ 排名 184: 領航高中歷史1
# ✅ 排名 185: 月考王：化學（全）
# ✅ 排名 186: 學測週計畫：數學A 1-4冊
# ✅ 排名 187: 無敵自修高中國文1
# ✅ 排名 188: DSM-5-TR®精神疾病診斷準則手冊
# ✅ 排名 189: Vocabulary 4001～7000：進階必考3000單字書
# ✅ 排名 190: 新編中國哲學史(一)(四版)
# ✅ 排名 191: 三國演義(上/下)(三版)
# ✅ 排名 192: 大眾傳播理論與實證(四版)
# ✅ 排名 193: 鬼滅之刃22
# ✅ 排名 194: 鏈鋸人10
# ✅ 排名 195: 鏈鋸人11
# ✅ 排名 196: 鬼滅之刃18
# ✅ 排名 197: 鬼滅之刃19
# ✅ 排名 198: 鬼滅之刃23（完）
# ✅ 排名 199: 憲法理論與政府體制(增訂九版)
# ✅ 排名 200: 新譯世說新語(上/下)(四版)
# Processing page 6
# ✅ 排名 201: 新譯六祖壇經(三版)
# ✅ 排名 202: 新譯菜根譚(三版)
# ✅ 排名 203: 新譯八識規矩頌(二版)
# ✅ 排名 204: 國際私法論(修訂六版)
# ✅ 排名 205: 山洞裡的小不點
# ✅ 排名 206: 我的樂器家族-我的小小探索音樂書
# ✅ 排名 207: 六個抬棺人
# ✅ 排名 208: 全國高中月考期考試題挖挖哇：國文3
# ✅ 排名 209: 贏家英文主題式翻譯
# ✅ 排名 210: 大滿貫英語文法總匯
# ✅ 排名 211: 當我告別教職：一位離職教師的沉痛告白與深情祝福
# ✅ 排名 212: 領航高中英文1（AB二冊）
# ✅ 排名 213: 抄寫英語的奇蹟：1天10分鐘，英語和人生都起飛
# ✅ 排名 214: 被討厭的勇氣：自我啟發之父「阿德勒」的教導
# ✅ 排名 215: 新日檢完勝500題N3：文字．語彙．文法
# ✅ 排名 216: 北曲新譜
# ✅ 排名 217: 經濟學概論
# ✅ 排名 218: 圖解十二經絡調筋術
# ✅ 排名 219: 錫安長老會紀要：由世界政府來征服世界
# ✅ 排名 220: Dog Man #6: Brawl of the Wild (全彩平裝本)(Graphic Novel)
# ✅ 排名 221: The Screaming Goat 療癒小廢物
# ✅ 排名 222: Mr. Men Little Miss Advent Calendar (降臨曆)
# ✅ 排名 223: 世界盡頭的咖啡館：這一生，我為何而存在？【「穿越迷霧」暢銷限量PVC書衣版】
# ✅ 排名 224: 有錢到老後：讓錢活得比你久，嫺人用三桶金計畫打造不怕老、不怕窮的退休理財指南
# ✅ 排名 225: 數位民主治理：主權、創新與社會發展的公共反思
# ✅ 排名 226: 圖解易經：讀懂《易經》的第一本書，全譯插圖暢銷版
# ✅ 排名 227: 文言文15篇大講堂（暨經典選文＋混合題型訓練）
# ✅ 排名 228: 新刑法總則
# ✅ 排名 229: 國文掌心雷(108課綱)
# ✅ 排名 230: 想哭就哭成一座噴水池
# ✅ 排名 231: 國文百閱：推薦選文PLUS(二版)(附解答本)
# ✅ 排名 232: 侵權行為法原理
# ✅ 排名 233: 全國高中月考期考試題挖挖哇：選修化學I（全）
# ✅ 排名 234: 全國高中月考期考試題挖挖哇：選修物理I（全）
# ✅ 排名 235: 天機：九十九句處世箴言，開悟有車進階有道
# ✅ 排名 236: 如果西遊是一群喵01：《如果歷史是一群喵》作者最新力作，附【首卷特典】拉頁
# ✅ 排名 237: 執行長日記：關於事業與人生的33條法則【耀黑燙金版】
# ✅ 排名 238: 解構美中冷戰：看懂比美蘇更複雜的新格局，從貿易戰到軍備競賽，台灣身處關鍵十字路口
# ✅ 排名 239: 褪黑激素神奇療癒力：讓你有好睡眠、還可抗衰老、增強免疫力，降低癌症、糖尿病、心臟病、失智等疾病風險
# ✅ 排名 240: 科技共和國：硬實力、軟信念與西方未來：Palantir 帕蘭泰爾的思想起源
# Processing page 7
# ✅ 排名 241: 數學分析圖鑑：圖解x實例，從微積分到向量分析，一本搞定！
# ✅ 排名 242: 超圖解肌肉．關節．骨骼：掌握人體動作與運作機制
# ✅ 排名 243: 持續的技術：每天進步一點點，再忙的人也能做到的習慣養成法
# ✅ 排名 244: 地科掌心雷(108課綱)(二版)
# ✅ 排名 245: 漫畫老子道德經（典藏版）
# ✅ 排名 246: 好好學地理學測總複習講義
# ✅ 排名 247: 模模考英文科學測模考試題本
# ✅ 排名 248: 最新！新制多益TOEIC聽力題庫解析：最新收錄精準 10 回模擬試題！完整反映命題趨勢、大幅提升應考能力，黃金證書手到擒來！（雙書裝+2MP3+音檔下載QR碼）
# ✅ 排名 249: FIRE PUNCH炎拳03
# ✅ 排名 250: FIRE PUNCH炎拳04
# ✅ 排名 251: FIRE PUNCH炎拳01
# ✅ 排名 252: FIRE PUNCH炎拳02
# ✅ 排名 253: FIRE PUNCH炎拳06
# ✅ 排名 254: 鄉史補記
# ✅ 排名 255: 臺灣漫遊錄
# ✅ 排名 256: 植秀
# ✅ 排名 257: 富媽媽窮媽媽：陳重銘寫給不想一輩子窮忙的你，10個觀念從領薪水到領千萬股利
# ✅ 排名 258: 步步驚魂．股海入門：看清股市裡的謊言與真相，日本暢銷20年的零焦慮投資法
# ✅ 排名 259: 配息型ETF獲利放大術：運用「精準加碼」策略逆向布局，報酬率、配息率雙UP！
# ✅ 排名 260: 廟會與社會：民間信仰的祭典組織、巡境與陣頭
# ✅ 排名 261: 如何讓AI幫你代筆寫出你想要的銷魂文案：教你正確下指令，讓企劃案、簡報、履歷、論文、寫作一秒完成！
# ✅ 排名 262: 認得幾個字（完整新版）
# ✅ 排名 263: 不老，從髖關節開始：強化核心力量，打造柔軟度、穩定度與靈活度
# ✅ 排名 264: 地名的野生思考
# ✅ 排名 265: 普林斯頓微積分讀本(修訂版)（簡體書）
# ✅ 排名 266: 品質管理準則及會計師服務案件準則合訂本(中華民國一一三年二月版)
# ✅ 排名 267: 數學分析(原書第2版‧典藏版)（簡體書）
# ✅ 排名 268: 希臘羅馬神話漫畫31：羅馬的起源
# ✅ 排名 269: 自己的膝蓋自己救：退化性膝關節炎的真相【暢銷增訂版】
# ✅ 排名 270: 碳水循環：一輩子都瘦用的增肌減脂飲食法
# ✅ 排名 271: What If? 2: Additional Serious Scientific Answers to Absurd Hypothetical Questions
# ✅ 排名 272: UFO Cow Abduction 療癒小廢物
# ✅ 排名 273: 國文選
# ✅ 排名 274: 普通型高中歷史第三冊習作(附解答本)
# ✅ 排名 275: Dog Man #7: For Whom the Ball Rolls (全彩平裝本)(Graphic Novel)
# ✅ 排名 276: Dog Man #9: Grime and Punishment (全彩平裝本)(Graphic Novel)
# ✅ 排名 277: Dog Man #10: Mothering Heights (全彩平裝本)(Graphic Novel)
# ✅ 排名 278: 在黑暗中相遇：一場從終點回溯原點的靈魂告白，謝哲青2025全新創作！（限量附贈「黑暗．相遇」光影透卡）
# ✅ 排名 279: 史上最強1000種全食物營養完整圖鑑：探索110種食材，1000個OK和NG組合，全營養聖經！
# ✅ 排名 280: 補教名師的學霸英文：單字x文法x閱讀x寫作不卡關
# Processing page 8
# ✅ 排名 281: 華語文教學導論(修訂二版)
# ✅ 排名 282: 餐盒裡的食物從哪兒來？
# ✅ 排名 283: 我的小小禪樂-我的小小探索音樂書
# ✅ 排名 284: 新譯論語新編解義
# ✅ 排名 285: 新譯抱朴子(下)(二版)
# ✅ 排名 286: 新譯坐忘論
# ✅ 排名 287: 三民國語小辭典(二版)
# ✅ 排名 288: 簡易微積分
# ✅ 排名 289: 歡迎光臨恐龍百貨
# ✅ 排名 290: 我的第一本量子物理
# ✅ 排名 291: 嗨！太陽系的星朋友
# ✅ 排名 292: 民事訴訟法（修訂四版）
# ✅ 排名 293: 新譯莊子讀本(三版)
# ✅ 排名 294: 鬼滅之刃20
# ✅ 排名 295: 心酸記(精)
# ✅ 排名 296: 營養與飼料（上）
# ✅ 排名 297: 鏈鋸人07
# ✅ 排名 298: 鬼滅之刃21
# ✅ 排名 299: 鏈鋸人08
# ✅ 排名 300: 鏈鋸人04
# ✅ 排名 301: 韓國史：悲劇的循環與宿命(增訂八版)
# ✅ 排名 302: 新譯維摩詰經(二版)
# ✅ 排名 303: 新譯唐詩三百首(七版)
# ✅ 排名 304: 新譯李慈銘詩文選
# ✅ 排名 305: 新譯地藏菩薩本願經(三版)
# ✅ 排名 306: 古典小說選讀(修訂三版)
# ✅ 排名 307: 我的超級好朋友
# ✅ 排名 308: 東周列國志(上/下)(三版)
# ✅ 排名 309: 封神演義(上/下)(三版)
# ✅ 排名 310: 獅子在哪裡
# ✅ 排名 311: 新譯老子解義(三版)
# ✅ 排名 312: 語言學概論(四版)
# ✅ 排名 313: 測量學(修訂三版)
# ✅ 排名 314: 爺爺的神祕巨人
# ✅ 排名 315: 小小的寶藏－寄居蟹與海葵的共生(硬精裝)
# ✅ 排名 316: 我家能源從哪兒來？
# ✅ 排名 317: 發現莫札特-我的小小探索音樂書
# ✅ 排名 318: 新譯小窗幽記(下)
# ✅ 排名 319: 不肯沉默的公雞！
# ✅ 排名 320: 全新！新制多益TOEIC試題滿分一本通：6回完整試題＋詳解，掌握最新命題趨勢，一本搞定新制多益測驗！（附雙書裝＋2 MP3光碟＋音檔下載QR碼）
# Processing page 9
# ✅ 排名 321: 古代文化常識一網打盡
# ✅ 排名 322: 金融科技力2025年版
# ✅ 排名 323: 建築圖中的臺灣史
# ✅ 排名 324: 數獨隨身玩：皇后級
# ✅ 排名 325: 健康到最後：預防臥床，無憾善終的本事
# ✅ 排名 326: 彙音寶鑑（全）
# ✅ 排名 327: 一句頂一萬句
# ✅ 排名 328: 新譯戰國策(上/下)(三版)(限量刷金版)
# ✅ 排名 329: Harry Potter: Hedwig Owl Figurine 療癒小廢物
# ✅ 排名 330: 2026三民手札 星願流年
# ✅ 排名 331: 技術型高中英文第五冊課堂講義習作(C版)(附解析附冊)
# ✅ 排名 332: 台語憲章：還我台語社會運動宣言
# ✅ 排名 333: 西遊記(上/下)(三版)
# ✅ 排名 334: Little Big Feelings: My First Emotions 幼兒情緒管理硬頁操作書(盒裝共6本)(附音檔QRcode)
# ✅ 排名 335: 名偵探柯南：空想科學讀本
# ✅ 排名 336: 戰廢品（二十週年紀念新版，《紐約時報》十大好書、美國筆會／福克納小說獎，普立茲獎入圍，哈金經典長篇小說）
# ✅ 排名 337: 草法津梁：智永〈千字文〉真草對照要義
# ✅ 排名 338: 懂得駕馭AI的追問思維：日本思考訓練權威教你37道練習，洞察問題背後的「為什麼」，讓你贏得好結果
# ✅ 排名 339: 老闆要學會的27種盈利模式
# ✅ 排名 340: 微積分學習要訣
# ✅ 排名 341: 【圖解】邊畫邊解決的視覺化溝通術：MIT、米其林、歐洲太空總署、世界經濟論壇⋯⋯全球頂尖團隊都在用的圖像工作法
# ✅ 排名 342: 董氏奇穴原理解構（簡體書）
# ✅ 排名 343: 基礎化學與生活(第6版)（簡體書）
# ✅ 排名 344: 漫才‧精進篇：話藝漫才的創作與表演技巧（簡體書）
# ✅ 排名 345: 漫才‧入門篇：如何成為一名漫才表演者（簡體書）
# ✅ 排名 346: 槓桿ETF投資法：用50正2輕鬆打敗0050＆0056，提早退休
# ✅ 排名 347: 文言文很好用：妙筆生花要形容詞，驚人不休全憑數詞、量詞－引經據典，言之有物、談吐得宜，提升素養的最快方法。
# ✅ 排名 348: 機器人學導論(原書第4版)（簡體書）
# ✅ 排名 349: 崴爺的超脊筋膜治痛全書：人氣物理治療師林子崴，教你保養筋膜、善待脊椎、調整姿勢、無痛生活
# ✅ 排名 350: 日語副詞大全：學好副詞，提升日語溝通能力
# ✅ 排名 351: 文言文很好用：你一定想用的絕妙好詞（名詞、動詞）－引經據典，言之有物、談吐得宜，提升素養的最快方法。
# ✅ 排名 352: 寫給高中生的超簡單圖解生物化學
# ✅ 排名 353: 學會放下，心才自由：心也需要鍛鍊，才能自在生活。給所有感到疲憊、渴望喘口氣的你：最簡單卻最智慧的心靈療癒良方。
# ✅ 排名 354: 數位國土保衛戰：從數位身分證、AI到電子投票，揭開臺灣數位化暗藏的國安危機
# ✅ 排名 355: 獨角獸，炒作與泡沫：新科技熱門話題，是真商機還是假訊號？美日新加坡資歷超過45年，卡內基美隆博士教你如何識別、避開、與充分利用。
# ✅ 排名 356: X萬獸探險隊Ⅳ04：獨角巨神兵 庇里牛斯羱羊VS板齒犀VS德州長角牛（附學習單）
# ✅ 排名 357: 為什麼全世界都在缺貨？：跨越全球的供應鏈風暴，揭開穩定生活的幻象
# ✅ 排名 358: 破局致富：從認知覺醒到財務自由，看懂資本遊戲規則，做出改變選擇
# ✅ 排名 359: 95個日常小習慣，穩定血糖，享受健康人生
# ✅ 排名 360: 造化之通：自在的遊戲三昧
# Processing page 10
# ✅ 排名 361: 人電學：以無形之氣，調理有形之血
# ✅ 排名 362: 鬼滅之刃03
# ✅ 排名 363: FIRE PUNCH炎拳05
# ✅ 排名 364: 富爸爸，窮爸爸（25週年紀念版）
# ✅ 排名 365: 全知讀者視角01
# ✅ 排名 366: 小學生精解國語辭典(道林紙本)(增訂六版)
# ✅ 排名 367: 張忠謀自傳全集（上下冊）
# ✅ 排名 368: 全知讀者視角07
# ✅ 排名 369: 過好這一生
# ✅ 排名 370: 你想要的一切，宇宙早已為你預備
# ✅ 排名 371: 鬼滅之刃04
# ✅ 排名 372: 鬼滅之刃05
# ✅ 排名 373: 阿甘投資法：不看盤、不選股、不挑買點也能穩穩賺
# ✅ 排名 374: 全新！學自然發音不用背：入學前學好自然發音！看字發音、聽音拼字、手寫練字，單字能說會寫記得住，一輩子都受用！（附 QR 碼線上音檔＋發音律動操線上影片）
# ✅ 排名 375: 宋朝的四季餐桌：復刻60多道時令美饌，還原千年前家常滋味
# ✅ 排名 376: 植觀達人 從研究到發表
# ✅ 排名 377: 金剛經說甚麼（新訂版）
# ✅ 排名 378: 先天解六祖壇經
# ✅ 排名 379: 技術型高中英文第一冊職場多益TOEIC Up!(A版)(附解析夾冊)
# ✅ 排名 380: 經絡穴位反射區大圖冊（暢銷版）
# ✅ 排名 381: 東京玩遍東京與近郊深度遊！（2026-27最新版）
# ✅ 排名 382: 彭述之回憶錄 （上、下卷）
# ✅ 排名 383: Peppa Pig: Practise with Peppa: Wipe-Clean First Words (寫字書)
# ✅ 排名 384: Maisy First Experiences Set (10平裝本)
# ✅ 排名 385: 工程師勳仔40歲前退休計畫：指數節稅多元收益投資法 低風險避開0050正2盲點
# ✅ 排名 386: Ryan爸爸的高效存股法：ETF╳3大類股 打造月領10萬股息方程式
# ✅ 排名 387: 不退轉法輪經講義第十輯
# ✅ 排名 388: 解密粒線體：李政家博士的健腦科技養生法
# ✅ 排名 389: 課本沒教的台灣華語句型50【全新修訂版】 Taiwan Mandarin: 50 Patterns Not in Your Textbook（隨書附名師親錄台灣華語朗讀音檔QR Code）
# ✅ 排名 390: 猶太商法：日本麥當勞創始人：藤田田的不朽商戰名著，「做生意要賺大錢，你就得瞄準有錢人、女人及嘴巴！」
# ✅ 排名 391: 圖解觀世音菩薩普門品：慈眼視眾生，千處祈求千處現
# ✅ 排名 392: 科學家．作家魂：從數據整理、撰寫技巧到投稿策略，寫出讓期刊難以拒絕的研究論文
# ✅ 排名 393: 金錢多重宇宙：鯖魚、聯準會、比特幣……從貨幣看懂通膨、金融危機、關稅貿易戰
# ✅ 排名 394: 自己的腰痛，自己救！：骨科名醫傳授22種運動Ｘ6動作Ｘ5姿勢‧任何腰部不適都能解除
# ✅ 排名 395: 老屋熟成：說32好屋故事，獻給房屋高齡化時代，從活化想修復的永續實踐指南
# ✅ 排名 396: 財富自由的階梯：5年賺到400萬，10年累積1,000萬。我這樣精選ETF，年賺20％。
# ✅ 排名 397: 你的人生，他們六個說了算！：決定你一生的六種物質
# ✅ 排名 398: 史賓諾莎診療室【本屋大賞TOP4，日本藝文界名人一致盛讚之傑作！】
# ✅ 排名 399: 先天解般若心經
# ✅ 排名 400: 法王宗喀巴大師以單傳方式賜予克主一切智者的甚深殊勝上師瑜伽（藏漢對照）
# Processing page 11
# ✅ 排名 401: 金丹真傳
# ✅ 排名 402: 2026丙午馬年開運聖經
# ✅ 排名 403: 世界體系分析引論
# ✅ 排名 404: 雅思IELTS單字走著瞧（附「Youtor App」內含VRP虛擬點讀筆＋防水書套）
# ✅ 排名 405: 北洋軍閥史(全二冊)(修訂版)（簡體書）
# ✅ 排名 406: 郝萬山傷寒論講稿(增訂本)（簡體書）
# ✅ 排名 407: 跨越鴻溝：顛覆性產品營銷指南(原書第3版)（簡體書）
# ✅ 排名 408: 機械識圖完全自學一本通(圖解雙色版)（簡體書）
# ✅ 排名 409: FreeCAD從入門到綜合實戰（簡體書）
# ✅ 排名 410: 愛撫按摩指南：增加親密度和性慾的祕訣，讓你擁有美好性愛！
# ✅ 排名 411: 鏈鋸人12
# ✅ 排名 412: 「什麼都有」的披薩
# ✅ 排名 413: 漫畫文學經典系列：金銀島(爆笑圖解版)
# ✅ 排名 414: 漫畫文學經典系列：遠大前程(爆笑圖解版)
# ✅ 排名 415: 世界盡頭的咖啡館：這一生，我為何而存在？（全球每19秒售出1本！療癒千萬人的暢銷經典，定位人生的神奇之書）
# ✅ 排名 416: 黃仁勳傳：輝達創辦人如何打造全球最搶手的晶片
# ✅ 排名 417: 達克比辦案16：激流東西軍：臺灣河川特色與淡水魚的來源
# ✅ 排名 418: 女警艾拉01：深林冷案（北歐犯罪書寫最高榮譽玻璃鑰匙獎）
# ✅ 排名 419: 巴菲特的人生之道：成功致富與圓滿人生的永恆智慧
# ✅ 排名 420: 詹惟中2026開運農民曆：保證讓你整年好運、財源快馬加鞭一直來！【首刷限量馬上有錢五帝錢吊飾】
# ✅ 排名 421: 袒露的心
# ✅ 排名 422: 你們公司到底在賣什麼？：找到賣點，生意就來！傳奇策略顧問師不藏私行銷祕笈全公開
# ✅ 排名 423: 一次看穿都更×合建契約陷阱：良心律師專業解碼老屋改建眉角（新版）
# ✅ 排名 424: The Idiot 白癡
# ✅ 排名 425: Shifty McGifty and Slippery Sam: Train Trouble
# ✅ 排名 426: 鏈鋸人18
# ✅ 排名 427: The Boy Who Made Monsters
# ✅ 排名 428: Maisy's Christmas Eve (平裝本) 廖彩杏老師推薦有聲書第35週
# ✅ 排名 429: 巴菲特寫給股東的信【時報五十‧金句透卡組限量版】
# ✅ 排名 430: Rise of the Earth Dragon: A Branches Book (Dragon Masters #1)(平裝本)
# ✅ 排名 431: Bluey: Let's Play Outside!: Magnet Book (磁鐵遊戲書)
# ✅ 排名 432: 普通型高中歷史第三冊地圖學習指南
# ✅ 排名 433: 普通型高中公民與社會第三冊學習攻略習作
# ✅ 排名 434: 技術型高中數學B第三冊習作
# ✅ 排名 435: 普通型高中數學第四冊A教學講義(含解答本)
# ✅ 排名 436: 雲海玉弓緣（全三冊）
# ✅ 排名 437: 氣功築基法（原理與練習）
# ✅ 排名 438: 臺北人
# ✅ 排名 439: 百年孤寂【平裝典藏版】：首度正式授權繁體中文版！出版50週年紀念全新譯本
# ✅ 排名 440: 哈利波特01：神秘的魔法石【繁體中文版20週年紀念】
# Processing page 12
# ✅ 排名 441: 世界上最透明的故事（日本出版界話題作，只有紙本書可以體驗的感動）
# ✅ 排名 442: 世界上最透明的故事【春季限定版】：臺日出版界話題作，只有紙本書可以體驗的感動
# ✅ 排名 443: 張澄基先生佛學翻譯與論著全集（四）：岡波巴大師傳
# ✅ 排名 444: 寒玉堂畫論
# ✅ 排名 445: 脊椎徒手治療：軟組織與脊椎鬆動術之治療與居家運動
# ✅ 排名 446: 國富論【權威中譯本】（上）
# ✅ 排名 447: 國富論【權威中譯本】（下）
# ✅ 排名 448: 向下的移動：基督的捨己之路
# ✅ 排名 449: 曾國藩家書：一代洞悉內聖外王之術的名臣家書
# ✅ 排名 450: 山爺
# ✅ 排名 451: 全新！新制多益TOEIC題庫解析：狠準 6 回聽力＋閱讀模擬試題，完全反映最新命題趨勢、全方位建立新制多益實戰能力！（附雙書裝＋2 MP3光碟＋音檔下載QR碼）（共二冊）
# ✅ 排名 452: 左先生與右先生
# ✅ 排名 453: 拉拉上學又遲到啦
# ✅ 排名 454: 世界上最強壯的媽媽
# ✅ 排名 455: 新譯宋詞三百首
# ✅ 排名 456: 胡桃鉗-我的小小音樂圖畫書
# ✅ 排名 457: 好吃的服裝店：甜蜜歡樂舞會
# ✅ 排名 458: 小豆子的大冒險
# ✅ 排名 459: 我眼中的世界-資訊圖像繪本
# ✅ 排名 460: 我的馬戲團音樂-我的小小音樂圖畫書
# ✅ 排名 461: 新譯悟真篇
# ✅ 排名 462: 不選股，我才賺到錢：財經記者從投資黑歷史中學到的真教訓，持續買進才是唯一解
# ✅ 排名 463: 誰製造了貧窮？：史丹佛經濟學家對貧富不均的思辨（精彩回應《國家為什麼會失敗》、皮凱提《二十一世紀資本論》的論證）
# ✅ 排名 464: 目的思維：用最小努力，獲得最大成果的方法（附「思考提問地圖」，幫助你改變視野、掌握問題全貌）
# ✅ 排名 465: 雪是誰的?
# ✅ 排名 466: 水滸傳(上/下)(四版)
# ✅ 排名 467: 我是小巴
# ✅ 排名 468: 金瓶梅(上/下)(四版)
# ✅ 排名 469: 我的第一本相對論
# ✅ 排名 470: 行政法導論（修訂十三版）
# ✅ 排名 471: 字裡行間覓數跡
# ✅ 排名 472: 新譯易經繫辭傳解義(三版)
# ✅ 排名 473: 新譯妙法蓮華經(三版)
# ✅ 排名 474: 新譯大乘起信論(三版)
# ✅ 排名 475: 藤本樹短篇集 22-26（全）
# ✅ 排名 476: 道德經講義
# ✅ 排名 477: 鬼滅之刃12
# ✅ 排名 478: 鬼滅之刃14
# ✅ 排名 479: 鬼滅之刃16
# ✅ 排名 480: 統測關鍵字彙
# Processing page 13
# ✅ 排名 481: 記錄你的每一天：不論好心情、壞心情，都是美好的一天
# ✅ 排名 482: 簽下古羅馬志願役的我竟然遇到了這種事？！
# ✅ 排名 483: 色彩魔術師：透納
# ✅ 排名 484: 新譯增廣賢文‧千字文(三版)
# ✅ 排名 485: 儒林外史(四版)
# ✅ 排名 486: 找到一個家
# ✅ 排名 487: 我36歲就退休：靠被動收入達到財務自由
# ✅ 排名 488: 新譯詩經讀本(上/下)(平)(三版)
# ✅ 排名 489: Linguaskill領思高頻字彙 (附習題本附冊)
# ✅ 排名 490: 內向軟腳蝦的超速行銷：哈佛、國際頂尖期刊實證，不見面、不打電話、不必拜託別人，簡單運用行為科學，只寫一句話也能不著痕跡改變人心
# ✅ 排名 491: 史坎德：獨角獸竊盜者
# ✅ 排名 492: 臺灣民事習慣調查報告
# ✅ 排名 493: 火災動力學數值模擬：FDS/PyroSim軟件原理與應用（簡體書）
# ✅ 排名 494: 精編活用辭典
# ✅ 排名 495: 微積分的歷史步道(二版)
# ✅ 排名 496: 新譯華嚴經入法界品(上)(二版)
# ✅ 排名 497: 新譯華嚴經入法界品(下)(二版)
# ✅ 排名 498: 新譯宋詞三百首(修訂三版)
# ✅ 排名 499: 中國星占揭秘
# ✅ 排名 500: 孔夫子的偶像：周公
# 資料已保存到 C:/Users/HP/Desktop/project/book-ranking/ranking_result/sanmin/sanmin_all_categories_20251125.csv
# 共爬取 500 筆資料
